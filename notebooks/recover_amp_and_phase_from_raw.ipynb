# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/samples/clap_raw.csv", header=None, index_col=None)
df.loc[:, 1:] = df.loc[:, 1:].apply(lambda x: [complex(x_) for x_ in x])
df.head()
# Out:
#              0                                               1   \
# 0  1.699438e+09  (-0.020443112694549338+0.0036555772356140492j)
# 1  1.699438e+09   (-0.008609122594154668-0.019050592226930094j)
# 2  1.699438e+09    (0.020436501464116907-0.004389234924577776j)
# 3  1.699438e+09   (-0.014525085394367466-0.014930167457158592j)
# 4  1.699438e+09   (-0.004905943380908039+0.020407563294546457j)
#
#                                                2   \
# 0       (-0.02041499286966-0.006017642526318512j)
# 1    (0.0006398672198358199-0.02149372161175777j)
# 2    (0.020436501464116907+0.005898908083349749j)
# 3  (-0.0060762309418668685-0.020601316336234334j)
# 4   (-0.013556660111739964+0.016604731443073364j)
#
#                                               3   \
# 0   (-0.01673129580915661-0.014116152094448099j)
# 1    (0.008870886456814777-0.02027215691934393j)
# 2    (0.016242964911972534+0.01442576573937664j)
# 3  (0.0029223777387073985-0.021932300256833744j)
# ...

# %%
# amplitude
np.abs(df.loc[0, 1])
# Out:
# 0.02076738071032512

# %%
# phase
np.angle(df.loc[0, 1])
# Out:
# 2.9646457702939366
